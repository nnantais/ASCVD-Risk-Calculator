# %%
import requests
import os
from flask import Flask, request, render_template
from dotenv import load_dotenv

# %%
FHIR_SERVER_BASE_URL="http://pwebmedcit.services.brown.edu:9091/fhir"

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

# %%
! pip3 install -r requirements.txt

# %%
s = requests.Session()

# %%
def request_patient(patient_id, credentials):

    req = requests.get(FHIR_SERVER_BASE_URL + "/Patient/" + str(patient_id), auth = credentials)

    print(f"Requests status: {req.status_code}")

    response = req.json()
    print(response.keys())

    return response

# %%
patient_id =14

credentials = (username, password)

req = s.get("http://pwebmedcit.services.brown.edu:9091/fhir" + f"/Patient?patient={patient_id}", auth=credentials)


if req.status_code == 200:
    medications = req.json()['entry']
    patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
    patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
    # Convert patient details into set of tuples to ensure uniqueness
    unique_patients = set((patient['id'], patient['name'][0]['given'][0], patient['name'][0]['family'], patient['gender'], patient['birthDate']) for patient in patients)

    total_patients = len(unique_patients)
    print(total_patients)

else:
    print("None")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       8 if req.status_code == 200:
#       9     medications = req.json()['entry']
# ---> 10     patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
#      11     patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
#      12     # Convert patient details into set of tuples to ensure uniqueness
#
# Cell In[5], line 10, in <listcomp>(.0)
#       8 if req.status_code == 200:
#       9     medications = req.json()['entry']
# ---> 10     patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
#      11     patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
#      12     # Convert patient details into set of tuples to ensure uniqueness
#
# KeyError: 'subject'

# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

credentials = (username, password)
patient_id = 2

# Correctly format the URL to include the reference to the patient
url = f"http://pwebmedcit.services.brown.edu:9090/fhir/Observation?patient={patient_id}"
response = requests.get(url, auth=credentials)
observation_json = response.json()

# Display the results
import json
print(json.dumps(observation_json, indent=2))
# Out:
# {
#   "resourceType": "Bundle",
#   "id": "9a4d7d06-b898-4444-9949-acf0541eba1d",
#   "meta": {
#     "lastUpdated": "2024-07-12T19:07:09.679+00:00"
#   },
#   "type": "searchset",
#   "total": 679,
#   "link": [
#     {
#       "relation": "self",
#       "url": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation?patient=2"
#     },
#     {
#       "relation": "next",
#       "url": "http://pwebmedcit.services.brown.edu:9090/fhir?_getpages=9b2521ac-a04b-4efc-83d8-89c3d621655d&_getpagesoffset=100&_count=100&_pretty=true&_bundletype=searchset"
#     }
#   ],
#   "entry": [
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-308",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-308",
#         "identifier": [
#           {
#             "value": "93029-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93029-7",
#               "display": "How often do you see or talk to people that you care about and feel close to [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-307",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-307",
#         "identifier": [
#           {
#             "value": "93028-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93028-9",
#               "display": "Have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility in past 1 year [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-306",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-306",
#         "identifier": [
#           {
#             "value": "93038-8"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93038-8",
#               "display": "Stress level"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-305",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-305",
#         "identifier": [
#           {
#             "value": "93026-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93026-3",
#               "display": "Do you feel physically and emotionally safe where you currently live [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-304",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-304",
#         "identifier": [
#           {
#             "value": "69453-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "69453-9",
#               "display": "Cause of death [US Standard Certificate of Death]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/65"
#         },
#         "effectiveDateTime": "1988-05-07T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-303",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-303",
#         "identifier": [
#           {
#             "value": "76501-6"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "76501-6",
#               "display": "Within the last year, have you been afraid of your partner or ex-partner"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-302",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-302",
#         "identifier": [
#           {
#             "value": "93027-1"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93027-1",
#               "display": "Are you a refugee"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-301",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-301",
#         "identifier": [
#           {
#             "value": "82667-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "82667-7",
#               "display": "Total score [DAST-10]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-300",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-300",
#         "identifier": [
#           {
#             "value": "55758-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "55758-7",
#               "display": "Patient Health Questionnaire 2 item (PHQ-2) total score [Reported]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-299",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-299",
#         "identifier": [
#           {
#             "value": "76504-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "76504-0",
#               "display": "Total score [HARK]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-298",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-298",
#         "identifier": [
#           {
#             "value": "56051-6"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "56051-6",
#               "display": "Hispanic or Latino"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-297",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-297",
#         "identifier": [
#           {
#             "value": "32624-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "32624-9",
#               "display": "Race"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-296",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-296",
#         "identifier": [
#           {
#             "value": "93035-4"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93035-4",
#               "display": "Has season or migrant farm work been your or your family's main source of income at any point in past 2 years [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-295",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-295",
#         "identifier": [
#           {
#             "value": "93034-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93034-7",
#               "display": "Discharged from the U.S. Armed Forces"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-294",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-294",
#         "identifier": [
#           {
#             "value": "54899-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "54899-0",
#               "display": "Preferred language"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-293",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-293",
#         "identifier": [
#           {
#             "value": "63512-8"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63512-8",
#               "display": "How many people are living or staying at this address [#]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-292",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-292",
#         "identifier": [
#           {
#             "value": "71802-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "71802-3",
#               "display": "Housing status"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-291",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-291",
#         "identifier": [
#           {
#             "value": "93033-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93033-9",
#               "display": "Are you worried about losing your housing [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-290",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-290",
#         "identifier": [
#           {
#             "value": "56799-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "56799-0",
#               "display": "Address"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-289",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-289",
#         "identifier": [
#           {
#             "value": "82589-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "82589-3",
#               "display": "Highest level of education"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-288",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-288",
#         "identifier": [
#           {
#             "value": "67875-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "67875-5",
#               "display": "Employment status - current"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-287",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-287",
#         "identifier": [
#           {
#             "value": "76437-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "76437-3",
#               "display": "Primary insurance"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-286",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-286",
#         "identifier": [
#           {
#             "value": "63586-2"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63586-2",
#               "display": "What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-285",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-285",
#         "identifier": [
#           {
#             "value": "93031-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93031-3",
#               "display": "Have you or any family members you live with been unable to get any of the following when it was really needed in past 1 year [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-284",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-284",
#         "identifier": [
#           {
#             "value": "93030-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93030-5",
#               "display": "Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/57"
#         },
#         "effectiveDateTime": "1979-10-20T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-283",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-283",
#         "identifier": [
#           {
#             "value": "54899-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "54899-0",
#               "display": "Preferred language"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-282",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-282",
#         "identifier": [
#           {
#             "value": "63512-8"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63512-8",
#               "display": "How many people are living or staying at this address [#]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-281",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-281",
#         "identifier": [
#           {
#             "value": "71802-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "71802-3",
#               "display": "Housing status"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-280",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-280",
#         "identifier": [
#           {
#             "value": "93033-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93033-9",
#               "display": "Are you worried about losing your housing [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-279",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-279",
#         "identifier": [
#           {
#             "value": "56799-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "56799-0",
#               "display": "Address"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-278",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-278",
#         "identifier": [
#           {
#             "value": "82589-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "82589-3",
#               "display": "Highest level of education"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-277",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-277",
#         "identifier": [
#           {
#             "value": "67875-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "67875-5",
#               "display": "Employment status - current"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-276",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-276",
#         "identifier": [
#           {
#             "value": "76437-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "76437-3",
#               "display": "Primary insurance"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-275",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-275",
#         "identifier": [
#           {
#             "value": "63586-2"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63586-2",
#               "display": "What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-274",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-274",
#         "identifier": [
#           {
#             "value": "93031-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93031-3",
#               "display": "Have you or any family members you live with been unable to get any of the following when it was really needed in past 1 year [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-273",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-273",
#         "identifier": [
#           {
#             "value": "93030-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93030-5",
#               "display": "Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-272",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-272",
#         "identifier": [
#           {
#             "value": "93029-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93029-7",
#               "display": "How often do you see or talk to people that you care about and feel close to [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-271",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-271",
#         "identifier": [
#           {
#             "value": "93038-8"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93038-8",
#               "display": "Stress level"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-270",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-270",
#         "identifier": [
#           {
#             "value": "82667-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "82667-7",
#               "display": "Total score [DAST-10]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-269",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-269",
#         "identifier": [
#           {
#             "value": "55758-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "55758-7",
#               "display": "Patient Health Questionnaire 2 item (PHQ-2) total score [Reported]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-268",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-268",
#         "identifier": [
#           {
#             "value": "56051-6"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "56051-6",
#               "display": "Hispanic or Latino"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/28"
#         },
#         "effectiveDateTime": "1983-11-12T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
# ...
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63512-8",
#               "display": "How many people are living or staying at this address [#]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/68"
#         },
#         "effectiveDateTime": "1980-10-25T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-221",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-221",
#         "identifier": [
#           {
#             "value": "93034-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93034-7",
#               "display": "Discharged from the U.S. Armed Forces"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/68"
#         },
#         "effectiveDateTime": "1980-10-25T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-220",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-220",
#         "identifier": [
#           {
#             "value": "54899-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "54899-0",
#               "display": "Preferred language"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/68"
#         },
#         "effectiveDateTime": "1980-10-25T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-219",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-219",
#         "identifier": [
#           {
#             "value": "71802-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "71802-3",
#               "display": "Housing status"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-218",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-218",
#         "identifier": [
#           {
#             "value": "56799-0"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "56799-0",
#               "display": "Address"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-217",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-217",
#         "identifier": [
#           {
#             "value": "82589-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "82589-3",
#               "display": "Highest level of education"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-216",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-216",
#         "identifier": [
#           {
#             "value": "67875-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "67875-5",
#               "display": "Employment status - current"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-215",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-215",
#         "identifier": [
#           {
#             "value": "76437-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "76437-3",
#               "display": "Primary insurance"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-214",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-214",
#         "identifier": [
#           {
#             "value": "63586-2"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "63586-2",
#               "display": "What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-213",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-213",
#         "identifier": [
#           {
#             "value": "93031-3"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93031-3",
#               "display": "Have you or any family members you live with been unable to get any of the following when it was really needed in past 1 year [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-212",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-212",
#         "identifier": [
#           {
#             "value": "93030-5"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93030-5",
#               "display": "Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-211",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-211",
#         "identifier": [
#           {
#             "value": "93029-7"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93029-7",
#               "display": "How often do you see or talk to people that you care about and feel close to [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-210",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-210",
#         "identifier": [
#           {
#             "value": "93038-8"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93038-8",
#               "display": "Stress level"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     },
#     {
#       "fullUrl": "http://pwebmedcit.services.brown.edu:9090/fhir/Observation/-209",
#       "resource": {
#         "resourceType": "Observation",
#         "id": "-209",
#         "identifier": [
#           {
#             "value": "93028-9"
#           }
#         ],
#         "status": "final",
#         "category": [
#           {
#             "coding": [
#               {
#                 "system": "http://hl7.org/fhir/observation-category",
#                 "code": "exam"
#               }
#             ]
#           }
#         ],
#         "code": {
#           "coding": [
#             {
#               "system": "http://loinc.org",
#               "code": "93028-9",
#               "display": "Have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility in past 1 year [PRAPARE]"
#             }
#           ]
#         },
#         "subject": {
#           "reference": "Patient/2",
#           "display": "JORGE CANIPE"
#         },
#         "encounter": {
#           "reference": "Encounter/64"
#         },
#         "effectiveDateTime": "1984-11-17T00:00:00+00:00",
#         "performer": [
#           {
#             "reference": "Practitioner/13",
#             "display": "Joselyn874 Bayer639"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

FHIR_SERVER_BASE_URL = os.getenv("FHIR_SERVER_BASE_URL")
username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

def get_fhir_metadata(base_url, credentials):
    url = f"{base_url}/metadata"
    response = requests.get(url, auth=credentials)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch metadata. Status code: {response.status_code}")
        return None

def list_supported_resources(metadata):
    if not metadata:
        print("No metadata available")
        return

    resources = metadata.get('rest', [])[0].get('resource', [])
    supported_resources = [resource['type'] for resource in resources]
    
    print("Supported Resources:")
    for resource in supported_resources:
        print(resource)

if __name__ == "__main__":
    credentials = (username, password)
    metadata = get_fhir_metadata(FHIR_SERVER_BASE_URL, credentials)
    list_supported_resources(metadata)
# Out:
# Supported Resources:
# AllergyIntolerance
# ConceptMap
# Condition
# Device
# DeviceUseStatement
# DocumentReference
# Encounter
# Immunization
# Medication
# MedicationRequest
# MedicationStatement
# Observation
# OperationDefinition
# Organization
# Patient
# Practitioner
# Procedure
# Specimen

# %%
code ="18262-6"

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

s = requests.Session()

credentials = (username, password)

observation = s.get("http://pwebmedcit.services.brown.edu:9091/fhir" + f"/Observation?code={code}", auth=credentials)
observation
observation_json = observation.json()
observation_json
# Out:
# {'resourceType': 'Bundle',
#  'id': 'cfca23f3-ae75-4aee-9cc5-822508876be7',
#  'meta': {'lastUpdated': '2024-07-12T18:23:15.275+00:00'},
#  'type': 'searchset',
#  'total': 1186814,
#  'link': [{'relation': 'self',
#    'url': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation?code=18262-6'},
#   {'relation': 'next',
#    'url': 'http://pwebmedcit.services.brown.edu:9091/fhir?_getpages=402d8d1d-0b4e-497c-842a-2a2d52d61121&_getpagesoffset=100&_count=100&_pretty=true&_bundletype=searchset'}],
#  'entry': [{'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/47',
#    'resource': {'resourceType': 'Observation',
#     'id': '47',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/17'},
#     'effectiveDateTime': '2016-07-29T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1064',
#       'display': 'Mohammad578 Swaniawski813'}],
#     'valueString': '64.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/65',
#    'resource': {'resourceType': 'Observation',
#     'id': '65',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/14'},
#     'effectiveDateTime': '2019-08-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1064',
#       'display': 'Mohammad578 Swaniawski813'}],
#     'valueString': '88.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/78',
#    'resource': {'resourceType': 'Observation',
#     'id': '78',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/8'},
#     'effectiveDateTime': '2023-12-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/9',
#       'display': 'Sancho742 Arevalo970'}],
#     'valueString': '68.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/150',
#    'resource': {'resourceType': 'Observation',
#     'id': '150',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/2', 'display': 'SELENA GRANDA'},
#     'encounter': {'reference': 'Encounter/113'},
#     'effectiveDateTime': '2018-06-03T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/795',
#       'display': 'Jody426 Mosciski958'}],
#     'valueString': '77.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/181',
#    'resource': {'resourceType': 'Observation',
#     'id': '181',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/2', 'display': 'SELENA GRANDA'},
#     'encounter': {'reference': 'Encounter/116'},
#     'effectiveDateTime': '2021-06-20T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/795',
#       'display': 'Jody426 Mosciski958'}],
#     'valueString': '59.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/195',
#    'resource': {'resourceType': 'Observation',
#     'id': '195',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/2', 'display': 'SELENA GRANDA'},
#     'encounter': {'reference': 'Encounter/110'},
#     'effectiveDateTime': '2015-05-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/795',
#       'display': 'Jody426 Mosciski958'}],
#     'valueString': '89.3'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/254',
#    'resource': {'resourceType': 'Observation',
#     'id': '254',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/202'},
#     'effectiveDateTime': '1996-12-06T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/465',
#       'display': 'Ashlyn643 Smith67'}],
#     'valueString': '65.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/296',
#    'resource': {'resourceType': 'Observation',
#     'id': '296',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/153'},
#     'effectiveDateTime': '1995-10-05T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '78.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/319',
#    'resource': {'resourceType': 'Observation',
#     'id': '319',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/205'},
#     'effectiveDateTime': '1999-12-24T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/465',
#       'display': 'Ashlyn643 Smith67'}],
#     'valueString': '90.2'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/356',
#    'resource': {'resourceType': 'Observation',
#     'id': '356',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/137'},
#     'effectiveDateTime': '1996-04-16T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '79.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/412',
#    'resource': {'resourceType': 'Observation',
#     'id': '412',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/138'},
#     'effectiveDateTime': '2000-03-29T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '79.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/472',
#    'resource': {'resourceType': 'Observation',
#     'id': '472',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/143'},
#     'effectiveDateTime': '2000-03-30T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '79.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/493',
#    'resource': {'resourceType': 'Observation',
#     'id': '493',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/143'},
#     'effectiveDateTime': '2000-03-31T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '79.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/560',
#    'resource': {'resourceType': 'Observation',
#     'id': '560',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/145'},
#     'effectiveDateTime': '1996-04-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '79.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/599',
#    'resource': {'resourceType': 'Observation',
#     'id': '599',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/144'},
#     'effectiveDateTime': '1997-04-13T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '71.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/632',
#    'resource': {'resourceType': 'Observation',
#     'id': '632',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/144'},
#     'effectiveDateTime': '1997-04-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '71.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/676',
#    'resource': {'resourceType': 'Observation',
#     'id': '676',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/199'},
#     'effectiveDateTime': '1993-11-19T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/465',
#       'display': 'Ashlyn643 Smith67'}],
#     'valueString': '111.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/701',
#    'resource': {'resourceType': 'Observation',
#     'id': '701',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/139'},
#     'effectiveDateTime': '1997-04-12T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/11',
#       'display': 'Carl856 Halvorson124'}],
#     'valueString': '71.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/787',
#    'resource': {'resourceType': 'Observation',
#     'id': '787',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/3', 'display': 'CAPRICE MCDOE'},
#     'encounter': {'reference': 'Encounter/196'},
#     'effectiveDateTime': '1990-11-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/465',
#       'display': 'Ashlyn643 Smith67'}],
#     'valueString': '74.2'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/842',
#    'resource': {'resourceType': 'Observation',
#     'id': '842',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/4', 'display': 'GLENNA LEDDY'},
#     'encounter': {'reference': 'Encounter/244'},
#     'effectiveDateTime': '2018-05-04T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1159',
#       'display': 'Maddie576 Stroman228'}],
#     'valueString': '93.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/888',
#    'resource': {'resourceType': 'Observation',
#     'id': '888',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/4', 'display': 'GLENNA LEDDY'},
#     'encounter': {'reference': 'Encounter/241'},
#     'effectiveDateTime': '2015-04-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1159',
#       'display': 'Maddie576 Stroman228'}],
#     'valueString': '87.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/940',
#    'resource': {'resourceType': 'Observation',
#     'id': '940',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/4', 'display': 'GLENNA LEDDY'},
#     'encounter': {'reference': 'Encounter/247'},
#     'effectiveDateTime': '2021-05-21T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1159',
#       'display': 'Maddie576 Stroman228'}],
#     'valueString': '87.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1032',
#    'resource': {'resourceType': 'Observation',
#     'id': '1032',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/5', 'display': 'NOREEN WHELCHEL'},
#     'encounter': {'reference': 'Encounter/289'},
#     'effectiveDateTime': '2018-11-20T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/744',
#       'display': 'Mac103 Price929'}],
#     'valueString': '68.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1085',
#    'resource': {'resourceType': 'Observation',
#     'id': '1085',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/5', 'display': 'NOREEN WHELCHEL'},
#     'encounter': {'reference': 'Encounter/290'},
#     'effectiveDateTime': '2021-11-23T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/744',
#       'display': 'Mac103 Price929'}],
#     'valueString': '105.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1157',
#    'resource': {'resourceType': 'Observation',
#     'id': '1157',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/6', 'display': 'ZACKARY HOISETH'},
#     'encounter': {'reference': 'Encounter/318'},
#     'effectiveDateTime': '2018-06-19T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/705',
#       'display': 'Rusty501 Hegmann834'}],
#     'valueString': '87.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1165',
#    'resource': {'resourceType': 'Observation',
#     'id': '1165',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/6', 'display': 'ZACKARY HOISETH'},
#     'encounter': {'reference': 'Encounter/315'},
#     'effectiveDateTime': '2015-06-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/705',
#       'display': 'Rusty501 Hegmann834'}],
#     'valueString': '77.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1230',
#    'resource': {'resourceType': 'Observation',
#     'id': '1230',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/6', 'display': 'ZACKARY HOISETH'},
#     'encounter': {'reference': 'Encounter/321'},
#     'effectiveDateTime': '2021-07-06T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/705',
#       'display': 'Rusty501 Hegmann834'}],
#     'valueString': '92.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1270',
#    'resource': {'resourceType': 'Observation',
#     'id': '1270',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/7', 'display': 'JORGE WESOLOWSKI'},
#     'encounter': {'reference': 'Encounter/337'},
#     'effectiveDateTime': '2017-09-15T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/442',
#       'display': 'Erin498 Lang846'}],
#     'valueString': '74.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1284',
#    'resource': {'resourceType': 'Observation',
#     'id': '1284',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/7', 'display': 'JORGE WESOLOWSKI'},
#     'encounter': {'reference': 'Encounter/336'},
#     'effectiveDateTime': '2014-09-12T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/442',
#       'display': 'Erin498 Lang846'}],
#     'valueString': '94.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1295',
#    'resource': {'resourceType': 'Observation',
#     'id': '1295',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/7', 'display': 'JORGE WESOLOWSKI'},
#     'encounter': {'reference': 'Encounter/338'},
#     'effectiveDateTime': '2020-09-18T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/442',
#       'display': 'Erin498 Lang846'}],
#     'valueString': '99.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1328',
#    'resource': {'resourceType': 'Observation',
#     'id': '1328',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/367'},
#     'effectiveDateTime': '1994-12-31T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1273',
#       'display': 'Jaunita130 Dickinson688'}],
#     'valueString': '94.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1380',
#    'resource': {'resourceType': 'Observation',
#     'id': '1380',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/379'},
#     'effectiveDateTime': '2000-08-24T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '81.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1506',
#    'resource': {'resourceType': 'Observation',
#     'id': '1506',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/378'},
#     'effectiveDateTime': '2000-02-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '89.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1537',
#    'resource': {'resourceType': 'Observation',
#     'id': '1537',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/375'},
#     'effectiveDateTime': '1991-12-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1273',
#       'display': 'Jaunita130 Dickinson688'}],
#     'valueString': '61.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1591',
#    'resource': {'resourceType': 'Observation',
#     'id': '1591',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/343'},
#     'effectiveDateTime': '2000-08-23T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '81.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1607',
#    'resource': {'resourceType': 'Observation',
#     'id': '1607',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/370'},
#     'effectiveDateTime': '1998-01-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1273',
#       'display': 'Jaunita130 Dickinson688'}],
#     'valueString': '86.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1672',
#    'resource': {'resourceType': 'Observation',
#     'id': '1672',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/377'},
#     'effectiveDateTime': '2001-02-21T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '75.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1696',
#    'resource': {'resourceType': 'Observation',
#     'id': '1696',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/346'},
#     'effectiveDateTime': '2000-02-24T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '89.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1743',
#    'resource': {'resourceType': 'Observation',
#     'id': '1743',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/350'},
#     'effectiveDateTime': '1999-02-15T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '89.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1775',
#    'resource': {'resourceType': 'Observation',
#     'id': '1775',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/373'},
#     'effectiveDateTime': '2001-02-03T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1273',
#       'display': 'Jaunita130 Dickinson688'}],
#     'valueString': '78.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1817',
#    'resource': {'resourceType': 'Observation',
#     'id': '1817',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/8', 'display': 'HELENE WIEST'},
#     'encounter': {'reference': 'Encounter/344'},
#     'effectiveDateTime': '2001-02-20T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '75.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1949',
#    'resource': {'resourceType': 'Observation',
#     'id': '1949',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/9', 'display': 'ROSARIO OSCHMANN'},
#     'encounter': {'reference': 'Encounter/479'},
#     'effectiveDateTime': '2021-08-01T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/13',
#       'display': 'Franklin857 Bayer639'}],
#     'valueString': '101.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/1958',
#    'resource': {'resourceType': 'Observation',
#     'id': '1958',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/9', 'display': 'ROSARIO OSCHMANN'},
#     'encounter': {'reference': 'Encounter/473'},
#     'effectiveDateTime': '2015-06-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/13',
#       'display': 'Franklin857 Bayer639'}],
#     'valueString': '83.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2016',
#    'resource': {'resourceType': 'Observation',
#     'id': '2016',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/9', 'display': 'ROSARIO OSCHMANN'},
#     'encounter': {'reference': 'Encounter/476'},
#     'effectiveDateTime': '2018-07-15T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/13',
#       'display': 'Franklin857 Bayer639'}],
#     'valueString': '98.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2216',
#    'resource': {'resourceType': 'Observation',
#     'id': '2216',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/504'},
#     'effectiveDateTime': '1994-03-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '86.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2259',
#    'resource': {'resourceType': 'Observation',
#     'id': '2259',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/512'},
#     'effectiveDateTime': '1997-03-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '121.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2275',
#    'resource': {'resourceType': 'Observation',
#     'id': '2275',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/501'},
#     'effectiveDateTime': '1993-03-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '105.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2300',
#    'resource': {'resourceType': 'Observation',
#     'id': '2300',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/515'},
#     'effectiveDateTime': '1999-03-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '130.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2324',
#    'resource': {'resourceType': 'Observation',
#     'id': '2324',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/544'},
#     'effectiveDateTime': '1990-04-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '63.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2406',
#    'resource': {'resourceType': 'Observation',
#     'id': '2406',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/510'},
#     'effectiveDateTime': '1996-03-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '82.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2432',
#    'resource': {'resourceType': 'Observation',
#     'id': '2432',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/514'},
#     'effectiveDateTime': '1998-03-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '101.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2452',
#    'resource': {'resourceType': 'Observation',
#     'id': '2452',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/562'},
#     'effectiveDateTime': '1992-03-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '92.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2478',
#    'resource': {'resourceType': 'Observation',
#     'id': '2478',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/540'},
#     'effectiveDateTime': '1996-05-15T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '69.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2485',
#    'resource': {'resourceType': 'Observation',
#     'id': '2485',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/559'},
#     'effectiveDateTime': '1990-03-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '145.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2513',
#    'resource': {'resourceType': 'Observation',
#     'id': '2513',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/561'},
#     'effectiveDateTime': '1991-03-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '97.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2536',
#    'resource': {'resourceType': 'Observation',
#     'id': '2536',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/506'},
#     'effectiveDateTime': '1995-03-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '129.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2564',
#    'resource': {'resourceType': 'Observation',
#     'id': '2564',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/11', 'display': 'HERB MUHLBACH'},
#     'encounter': {'reference': 'Encounter/537'},
#     'effectiveDateTime': '1993-04-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/12',
#       'display': 'Patricia625 Kilback373'}],
#     'valueString': '57.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2714',
#    'resource': {'resourceType': 'Observation',
#     'id': '2714',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/13', 'display': 'MERILYN ORTE'},
#     'encounter': {'reference': 'Encounter/607'},
#     'effectiveDateTime': '1999-05-07T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/521',
#       'display': 'Adriane398 Strosin214'}],
#     'valueString': '72.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2741',
#    'resource': {'resourceType': 'Observation',
#     'id': '2741',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/13', 'display': 'MERILYN ORTE'},
#     'encounter': {'reference': 'Encounter/616'},
#     'effectiveDateTime': '2008-06-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/521',
#       'display': 'Adriane398 Strosin214'}],
#     'valueString': '64.3'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2785',
#    'resource': {'resourceType': 'Observation',
#     'id': '2785',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/13', 'display': 'MERILYN ORTE'},
#     'encounter': {'reference': 'Encounter/613'},
#     'effectiveDateTime': '2005-06-10T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/521',
#       'display': 'Adriane398 Strosin214'}],
#     'valueString': '73.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2815',
#    'resource': {'resourceType': 'Observation',
#     'id': '2815',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/13', 'display': 'MERILYN ORTE'},
#     'encounter': {'reference': 'Encounter/610'},
#     'effectiveDateTime': '2002-05-24T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/521',
#       'display': 'Adriane398 Strosin214'}],
#     'valueString': '94.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2852',
#    'resource': {'resourceType': 'Observation',
#     'id': '2852',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '149.0'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2886',
#    'resource': {'resourceType': 'Observation',
#     'id': '2886',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/648'},
#     'effectiveDateTime': '2018-06-03T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '145.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2909',
#    'resource': {'resourceType': 'Observation',
#     'id': '2909',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/652'},
#     'effectiveDateTime': '2023-07-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '89.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2950',
#    'resource': {'resourceType': 'Observation',
#     'id': '2950',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/645'},
#     'effectiveDateTime': '2015-05-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '130.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2978',
#    'resource': {'resourceType': 'Observation',
#     'id': '2978',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/649'},
#     'effectiveDateTime': '2019-06-09T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '149.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/2991',
#    'resource': {'resourceType': 'Observation',
#     'id': '2991',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/650'},
#     'effectiveDateTime': '2021-06-20T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '129.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3026',
#    'resource': {'resourceType': 'Observation',
#     'id': '3026',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/647'},
#     'effectiveDateTime': '2017-05-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}],
#     'valueString': '150.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3036',
#    'resource': {'resourceType': 'Observation',
#     'id': '3036',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '138.2'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3076',
#    'resource': {'resourceType': 'Observation',
#     'id': '3076',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
# ...
#     'encounter': {'reference': 'Encounter/702'},
#     'effectiveDateTime': '2022-05-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '138.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3364',
#    'resource': {'resourceType': 'Observation',
#     'id': '3364',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/701'},
#     'effectiveDateTime': '2021-05-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '92.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3369',
#    'resource': {'resourceType': 'Observation',
#     'id': '3369',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/694'},
#     'effectiveDateTime': '2015-05-29T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '148.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3423',
#    'resource': {'resourceType': 'Observation',
#     'id': '3423',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/722'},
#     'effectiveDateTime': '2014-07-19T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/26',
#       'display': 'Douglass930 Windler79'}],
#     'valueString': '71.2'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3499',
#    'resource': {'resourceType': 'Observation',
#     'id': '3499',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/693'},
#     'effectiveDateTime': '2014-05-29T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '98.3'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3537',
#    'resource': {'resourceType': 'Observation',
#     'id': '3537',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/698'},
#     'effectiveDateTime': '2018-05-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '132.0'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3562',
#    'resource': {'resourceType': 'Observation',
#     'id': '3562',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/695'},
#     'effectiveDateTime': '2016-05-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '85.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3586',
#    'resource': {'resourceType': 'Observation',
#     'id': '3586',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/699'},
#     'effectiveDateTime': '2019-05-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '112.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3596',
#    'resource': {'resourceType': 'Observation',
#     'id': '3596',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/725'},
#     'effectiveDateTime': '2017-08-05T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/26',
#       'display': 'Douglass930 Windler79'}],
#     'valueString': '57.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3627',
#    'resource': {'resourceType': 'Observation',
#     'id': '3627',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/728'},
#     'effectiveDateTime': '2020-08-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/26',
#       'display': 'Douglass930 Windler79'}],
#     'valueString': '92.6'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3668',
#    'resource': {'resourceType': 'Observation',
#     'id': '3668',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/703'},
#     'effectiveDateTime': '2023-05-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '128.1'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3678',
#    'resource': {'resourceType': 'Observation',
#     'id': '3678',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/16', 'display': 'CARMA SZOC'},
#     'encounter': {'reference': 'Encounter/697'},
#     'effectiveDateTime': '2017-05-28T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}],
#     'valueString': '130.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3716',
#    'resource': {'resourceType': 'Observation',
#     'id': '3716',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/901'},
#     'effectiveDateTime': '2020-03-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '121.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3726',
#    'resource': {'resourceType': 'Observation',
#     'id': '3726',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/899'},
#     'effectiveDateTime': '2019-11-08T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '114.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3763',
#    'resource': {'resourceType': 'Observation',
#     'id': '3763',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/885'},
#     'effectiveDateTime': '2017-05-19T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '131.0'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3781',
#    'resource': {'resourceType': 'Observation',
#     'id': '3781',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/886'},
#     'effectiveDateTime': '2017-08-18T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '134.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3794',
#    'resource': {'resourceType': 'Observation',
#     'id': '3794',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/872'},
#     'effectiveDateTime': '2015-04-17T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '144.3'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3814',
#    'resource': {'resourceType': 'Observation',
#     'id': '3814',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/896'},
#     'effectiveDateTime': '2019-05-31T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '139.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3856',
#    'resource': {'resourceType': 'Observation',
#     'id': '3856',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/898'},
#     'effectiveDateTime': '2019-09-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '120.3'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3867',
#    'resource': {'resourceType': 'Observation',
#     'id': '3867',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/737'},
#     'effectiveDateTime': '2021-03-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '134.9'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3903',
#    'resource': {'resourceType': 'Observation',
#     'id': '3903',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/865'},
#     'effectiveDateTime': '2014-04-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '128.8'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3925',
#    'resource': {'resourceType': 'Observation',
#     'id': '3925',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/894'},
#     'effectiveDateTime': '2018-11-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '138.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3950',
#    'resource': {'resourceType': 'Observation',
#     'id': '3950',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/873'},
#     'effectiveDateTime': '2015-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '160.7'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/3957',
#    'resource': {'resourceType': 'Observation',
#     'id': '3957',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/17', 'display': 'BERNARDINE ALLSTOTT'},
#     'encounter': {'reference': 'Encounter/874'},
#     'effectiveDateTime': '2015-08-21T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/6',
#       'display': 'Terrell212 Fadel536'}],
#     'valueString': '153.7'}}]}

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

# Get FHIR server credentials from environment variables
username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")
credentials = (username, password)

# Patient ID and Observation code to filter
patient_id = 1
code = "18262-6"

# Function to fetch observations with pagination
def fetch_observations(url, credentials):
    observations = []
    while url:
        response = requests.get(url, auth=credentials)
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        data = response.json()
        if 'entry' in data:
            observations.extend(data['entry'])
        else:
            print("No entries found in the response.")
        url = None
        for link in data.get('link', []):
            if link['relation'] == 'next':
                url = link['url']
                break
    return observations

# Base URL for fetching observations
base_url = "http://pwebmedcit.services.brown.edu:9091/fhir"
patient_observations_url = f"{base_url}/Observation?patient={patient_id}"

# Step 1: Retrieve all observations for the patient
all_observations = fetch_observations(patient_observations_url, credentials)

print(f"Total observations retrieved: {len(all_observations)}")

# Step 2: Filter observations by the specific code
filtered_observations = []
for entry in all_observations:
    observation = entry['resource']
    if 'code' in observation and 'coding' in observation['code']:
        for coding in observation['code']['coding']:
            if coding['code'] == code:
                filtered_observations.append(observation)
                print(f"Matching observation found: {observation['id']}")

# Step 3: Extract valueString from the filtered observations
if filtered_observations:
    for observation in filtered_observations:
        if 'valueString' in observation:
            print(f"Patient {patient_id} has observation {code} with value: {observation['valueString']}")
        else:
            print(f"Observation {observation['id']} does not have a valueString.")
else:
    print(f"No observations found for patient {patient_id} with code {code}.")
# Out:
# Failed to fetch data: 500
# Total observations retrieved: 100
# No observations found for patient 1 with code 18262-6.

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

# Get FHIR server credentials from environment variables
username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")
credentials = (username, password)

# Observation code to filter
code = "18262-6"

# Base URL for fetching observations
base_url = "http://pwebmedcit.services.brown.edu:9090/fhir"

# Function to fetch observations with pagination
def fetch_observations(url, credentials, limit=5):
    observations = []
    patient_ids = set()
    while url and len(patient_ids) < limit:
        response = requests.get(url, auth=credentials)
        if response.status_code != 200:
            print(f"Failed to fetch data: {response.status_code}")
            break
        data = response.json()
        if 'entry' in data:
            for entry in data['entry']:
                observation = entry['resource']
                if 'subject' in observation:
                    patient_reference = observation['subject']['reference']
                    patient_id = patient_reference.split('/')[1]
                    if patient_id not in patient_ids:
                        patient_ids.add(patient_id)
                        observations.append(entry)
                        if len(patient_ids) >= limit:
                            break
        else:
            print("No entries found in the response.")
        url = None
        for link in data.get('link', []):
            if link['relation'] == 'next':
                url = link['url']
                break
    return observations

# Fetch observations with the specific code, limited to 5 patients
observations_by_code_url = f"{base_url}/Observation?code={code}"
observations = fetch_observations(observations_by_code_url, credentials)

print(f"Total observations retrieved with code {code} for up to 5 patients: {len(observations)}")

# Extract and print observations for up to 5 patients
def get_observation_value(observation):
    if 'valueString' in observation:
        return observation['valueString']
    elif 'valueQuantity' in observation:
        return observation['valueQuantity']['value']
    elif 'valueCodeableConcept' in observation:
        return observation['valueCodeableConcept']['text']
    elif 'valueBoolean' in observation:
        return observation['valueBoolean']
    elif 'valueInteger' in observation:
        return observation['valueInteger']
    elif 'valueRange' in observation:
        return f"{observation['valueRange']['low']['value']} - {observation['valueRange']['high']['value']}"
    elif 'valueRatio' in observation:
        return f"{observation['valueRatio']['numerator']['value']} / {observation['valueRatio']['denominator']['value']}"
    elif 'valueSampledData' in observation:
        return observation['valueSampledData']['data']
    elif 'valueTime' in observation:
        return observation['valueTime']
    elif 'valueDateTime' in observation:
        return observation['valueDateTime']
    else:
        return 'N/A'

# Organize observations by patient
patient_observations = {}
for entry in observations:
    observation = entry['resource']
    patient_reference = observation['subject']['reference']
    patient_id = patient_reference.split('/')[1]
    if patient_id not in patient_observations:
        patient_observations[patient_id] = []
    patient_observations[patient_id].append(observation)

# Print observations for up to 5 patients
if patient_observations:
    for patient_id, observations in patient_observations.items():
        print(f"Patient {patient_id} has {len(observations)} observation(s) with code {code}:")
        for observation in observations:
            value = get_observation_value(observation)
            print(f"  - Observation ID: {observation['id']}, Value: {value}")
else:
    print(f"No patients found with observation code {code}.")
# Out:
# Total observations retrieved with code 18262-6 for up to 5 patients: 5
# Patient 2 has 1 observation(s) with code 18262-6:
#   - Observation ID: 175, Value: 113.5
# Patient 3 has 1 observation(s) with code 18262-6:
#   - Observation ID: 671, Value: 89.9
# Patient 5 has 1 observation(s) with code 18262-6:
#   - Observation ID: 917, Value: 69.1
# Patient 6 has 1 observation(s) with code 18262-6:
#   - Observation ID: 1021, Value: 99.3
# Patient 7 has 1 observation(s) with code 18262-6:
#   - Observation ID: 1110, Value: 80.3

# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()
s = requests.Session()
# Get FHIR server credentials from environment variables
username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")
credentials = (username, password)

FHIR_SERVER_BASE_URL = "http://pwebmedcit.services.brown.edu:9091/fhir"
patient_id = "1"
code = "18262-6"  # LOINC code for LDL Cholesterol
response = s.get("http://pwebmedcit.services.brown.edu:9091/fhir" + f"/Observation?patient={patient_id}&code={code}", auth=credentials)

observations = response.json()
observations
# Out:
# {'resourceType': 'Bundle',
#  'id': 'fc4fa8a5-004b-4543-8344-176156041cf3',
#  'meta': {'lastUpdated': '2024-07-12T19:17:54.673+00:00'},
#  'type': 'searchset',
#  'total': 3,
#  'link': [{'relation': 'self',
#    'url': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation?code=18262-6&patient=1'}],
#  'entry': [{'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/47',
#    'resource': {'resourceType': 'Observation',
#     'id': '47',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/17'},
#     'effectiveDateTime': '2016-07-29T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1064',
#       'display': 'Mohammad578 Swaniawski813'}],
#     'valueString': '64.5'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/65',
#    'resource': {'resourceType': 'Observation',
#     'id': '65',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/14'},
#     'effectiveDateTime': '2019-08-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/1064',
#       'display': 'Mohammad578 Swaniawski813'}],
#     'valueString': '88.4'}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/78',
#    'resource': {'resourceType': 'Observation',
#     'id': '78',
#     'identifier': [{'value': '18262-6'}],
#     'status': 'final',
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '18262-6',
#        'display': 'Cholesterol in LDL [Mass/volume] in Serum or Plasma by Direct assay'}]},
#     'subject': {'reference': 'Patient/1', 'display': 'SHELTON KINATYAN'},
#     'encounter': {'reference': 'Encounter/8'},
#     'effectiveDateTime': '2023-12-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/9',
#       'display': 'Sancho742 Arevalo970'}],
#     'valueString': '68.9'}}]}
