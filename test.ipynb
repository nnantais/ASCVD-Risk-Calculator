# %%
import requests
import os
from flask import Flask, request, render_template
from dotenv import load_dotenv

# %%
FHIR_SERVER_BASE_URL="http://pwebmedcit.services.brown.edu:9091/fhir"

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

# %%
! pip3 install -r requirements.txt

# %%
s = requests.Session()

# %%
def request_patient(patient_id, credentials):

    req = requests.get(FHIR_SERVER_BASE_URL + "/Patient/" + str(patient_id), auth = credentials)

    print(f"Requests status: {req.status_code}")

    response = req.json()
    print(response.keys())

    return response

# %%
patient_id =14

credentials = (username, password)

req = s.get("http://pwebmedcit.services.brown.edu:9091/fhir" + f"/Patient?patient={patient_id}", auth=credentials)


if req.status_code == 200:
    medications = req.json()['entry']
    patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
    patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
    # Convert patient details into set of tuples to ensure uniqueness
    unique_patients = set((patient['id'], patient['name'][0]['given'][0], patient['name'][0]['family'], patient['gender'], patient['birthDate']) for patient in patients)

    total_patients = len(unique_patients)
    print(total_patients)

else:
    print("None")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 10
#       8 if req.status_code == 200:
#       9     medications = req.json()['entry']
# ---> 10     patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
#      11     patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
#      12     # Convert patient details into set of tuples to ensure uniqueness
#
# Cell In[30], line 10, in <listcomp>(.0)
#       8 if req.status_code == 200:
#       9     medications = req.json()['entry']
# ---> 10     patient_ids = [entry['resource']['subject']['reference'].split('/')[-1] for entry in medications]
#      11     patients = [request_patient(patient_id, credentials) for patient_id in patient_ids]
#      12     # Convert patient details into set of tuples to ensure uniqueness
#
# KeyError: 'subject'

# %%
Patient_id = 14

load_dotenv()

username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")


credentials = (username, password)

condition = s.get("http://pwebmedcit.services.brown.edu:9091/fhir" + f"/Observation?patient={Patient_id}", auth=credentials)
condition
condition_json = condition.json()
condition_json
# Out:
# {'resourceType': 'Bundle',
#  'id': '2d7ec99f-e173-4099-af3e-053be3630efb',
#  'meta': {'lastUpdated': '2024-07-11T15:47:31.284+00:00'},
#  'type': 'searchset',
#  'total': 523,
#  'link': [{'relation': 'self',
#    'url': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation?patient=14'},
#   {'relation': 'next',
#    'url': 'http://pwebmedcit.services.brown.edu:9091/fhir?_getpages=5188ea3f-9f9e-4d9f-be2c-cb2af86e12f6&_getpagesoffset=100&_count=100&_pretty=true&_bundletype=searchset'}],
#  'entry': [{'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3226',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3226',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-25T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3225',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3225',
#     'identifier': [{'value': '741062008'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '741062008',
#        'display': 'Not in labor force'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/648'},
#     'effectiveDateTime': '2018-06-02T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3224',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3224',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/640'},
#     'effectiveDateTime': '2009-04-04T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3223',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3223',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-21T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3222',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3222',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-10T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3221',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3221',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/652'},
#     'effectiveDateTime': '2023-07-01T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3220',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3220',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/635'},
#     'effectiveDateTime': '2004-03-06T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3219',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3219',
#     'identifier': [{'value': '741062008'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '741062008',
#        'display': 'Not in labor force'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-13T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3218',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3218',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/637'},
#     'effectiveDateTime': '2006-03-18T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3217',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3217',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/643'},
#     'effectiveDateTime': '2013-05-04T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3216',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3216',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/647'},
#     'effectiveDateTime': '2017-05-27T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3215',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3215',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/650'},
#     'effectiveDateTime': '2021-06-19T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3214',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3214',
#     'identifier': [{'value': '160904001'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160904001',
#        'display': 'Part-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/649'},
#     'effectiveDateTime': '2019-06-08T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3213',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3213',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/638'},
#     'effectiveDateTime': '2007-03-24T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3212',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3212',
#     'identifier': [{'value': '424393004'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '424393004',
#        'display': 'Reports of violence in the environment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/645'},
#     'effectiveDateTime': '2015-05-16T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3211',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3211',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/645'},
#     'effectiveDateTime': '2015-05-16T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3210',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3210',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/626'},
#     'effectiveDateTime': '2010-04-10T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3209',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3209',
#     'identifier': [{'value': '160903007'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '160903007',
#        'display': 'Full-time employment'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/631'},
#     'effectiveDateTime': '2000-02-12T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3208',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3208',
#     'identifier': [{'value': '224299000'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://snomed.info/sct',
#        'code': '224299000',
#        'display': 'Received higher education'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/631'},
#     'effectiveDateTime': '2000-02-12T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3207',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3207',
#     'identifier': [{'value': '93027-1'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93027-1',
#        'display': 'Are you a refugee'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3206',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3206',
#     'identifier': [{'value': '93026-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93026-3',
#        'display': 'Do you feel physically and emotionally safe where you currently live [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3205',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3205',
#     'identifier': [{'value': '76501-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76501-6',
#        'display': 'Within the last year, have you been afraid of your partner or ex-partner'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3204',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3204',
#     'identifier': [{'value': '72166-2'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '72166-2',
#        'display': 'Tobacco smoking status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3203',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3203',
#     'identifier': [{'value': '93038-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93038-8',
#        'display': 'Stress level'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3202',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3202',
#     'identifier': [{'value': '63586-2'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63586-2',
#        'display': 'What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3201',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3201',
#     'identifier': [{'value': '54899-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '54899-0',
#        'display': 'Preferred language'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3200',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3200',
#     'identifier': [{'value': '93034-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93034-7',
#        'display': 'Discharged from the U.S. Armed Forces'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3199',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3199',
#     'identifier': [{'value': '93035-4'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93035-4',
#        'display': "Has season or migrant farm work been your or your family's main source of income at any point in past 2 years [PRAPARE]"}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3198',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3198',
#     'identifier': [{'value': '32624-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '32624-9',
#        'display': 'Race'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3197',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3197',
#     'identifier': [{'value': '56051-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56051-6',
#        'display': 'Hispanic or Latino'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3196',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3196',
#     'identifier': [{'value': '93028-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93028-9',
#        'display': 'Have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility in past 1 year [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3195',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3195',
#     'identifier': [{'value': '76437-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76437-3',
#        'display': 'Primary insurance'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3194',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3194',
#     'identifier': [{'value': '67875-5'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '67875-5',
#        'display': 'Employment status - current'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3193',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3193',
#     'identifier': [{'value': '82589-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '82589-3',
#        'display': 'Highest level of education'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3192',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3192',
#     'identifier': [{'value': '56799-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56799-0',
#        'display': 'Address'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3191',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3191',
#     'identifier': [{'value': '93033-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93033-9',
#        'display': 'Are you worried about losing your housing [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3190',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3190',
#     'identifier': [{'value': '71802-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '71802-3',
#        'display': 'Housing status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3189',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3189',
#     'identifier': [{'value': '63512-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63512-8',
#        'display': 'How many people are living or staying at this address [#]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3188',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3188',
#     'identifier': [{'value': '93029-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93029-7',
#        'display': 'How often do you see or talk to people that you care about and feel close to [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3187',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3187',
#     'identifier': [{'value': '93030-5'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93030-5',
#        'display': 'Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3186',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3186',
#     'identifier': [{'value': '93031-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93031-3',
#        'display': 'Have you or any family members you live with been unable to get any of the following when it was really needed in past 1 year [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/644'},
#     'effectiveDateTime': '2014-05-11T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/3',
#       'display': 'Chauncey770 Steuber698'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3185',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3185',
#     'identifier': [{'value': '93029-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93029-7',
#        'display': 'How often do you see or talk to people that you care about and feel close to [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3184',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3184',
#     'identifier': [{'value': '93026-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93026-3',
#        'display': 'Do you feel physically and emotionally safe where you currently live [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3183',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3183',
#     'identifier': [{'value': '93038-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93038-8',
#        'display': 'Stress level'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3182',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3182',
#     'identifier': [{'value': '82589-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '82589-3',
#        'display': 'Highest level of education'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3181',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3181',
#     'identifier': [{'value': '67875-5'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '67875-5',
#        'display': 'Employment status - current'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3180',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3180',
#     'identifier': [{'value': '76437-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76437-3',
#        'display': 'Primary insurance'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3179',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3179',
#     'identifier': [{'value': '63586-2'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63586-2',
#        'display': 'What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3178',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3178',
#     'identifier': [{'value': '93031-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93031-3',
#        'display': 'Have you or any family members you live with been unable to get any of the following when it was really needed in past 1 year [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3177',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3177',
#     'identifier': [{'value': '72166-2'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '72166-2',
#        'display': 'Tobacco smoking status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3176',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3176',
#     'identifier': [{'value': '93028-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93028-9',
#        'display': 'Have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility in past 1 year [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3175',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3175',
#     'identifier': [{'value': '70274-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '70274-6',
#        'display': 'Generalized anxiety disorder 7 item (GAD-7) total score [Reported.PHQ]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3174',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3174',
#     'identifier': [{'value': '56051-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56051-6',
#        'display': 'Hispanic or Latino'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3173',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3173',
#     'identifier': [{'value': '32624-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '32624-9',
#        'display': 'Race'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3172',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3172',
#     'identifier': [{'value': '93035-4'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93035-4',
#        'display': "Has season or migrant farm work been your or your family's main source of income at any point in past 2 years [PRAPARE]"}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3171',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3171',
#     'identifier': [{'value': '93034-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93034-7',
#        'display': 'Discharged from the U.S. Armed Forces'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3170',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3170',
#     'identifier': [{'value': '54899-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '54899-0',
#        'display': 'Preferred language'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3169',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3169',
#     'identifier': [{'value': '63512-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63512-8',
#        'display': 'How many people are living or staying at this address [#]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3168',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3168',
#     'identifier': [{'value': '82667-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '82667-7',
#        'display': 'Total score [DAST-10]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3167',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3167',
#     'identifier': [{'value': '55758-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '55758-7',
#        'display': 'Patient Health Questionnaire 2 item (PHQ-2) total score [Reported]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3166',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3166',
#     'identifier': [{'value': '76501-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76501-6',
#        'display': 'Within the last year, have you been afraid of your partner or ex-partner'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3165',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3165',
#     'identifier': [{'value': '93027-1'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93027-1',
#        'display': 'Are you a refugee'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3164',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3164',
#     'identifier': [{'value': '93030-5'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93030-5',
#        'display': 'Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/646'},
#     'effectiveDateTime': '2016-05-22T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
# ...
#        'display': 'What was your best estimate of the total income of all family members from all sources, before taxes, in last year [PhenX]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3147',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3147',
#     'identifier': [{'value': '54899-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '54899-0',
#        'display': 'Preferred language'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3146',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3146',
#     'identifier': [{'value': '63512-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63512-8',
#        'display': 'How many people are living or staying at this address [#]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3145',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3145',
#     'identifier': [{'value': '71802-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '71802-3',
#        'display': 'Housing status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3144',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3144',
#     'identifier': [{'value': '93033-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93033-9',
#        'display': 'Are you worried about losing your housing [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3143',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3143',
#     'identifier': [{'value': '56799-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56799-0',
#        'display': 'Address'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3142',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3142',
#     'identifier': [{'value': '82589-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '82589-3',
#        'display': 'Highest level of education'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3141',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3141',
#     'identifier': [{'value': '67875-5'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '67875-5',
#        'display': 'Employment status - current'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3140',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3140',
#     'identifier': [{'value': '76437-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76437-3',
#        'display': 'Primary insurance'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3139',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3139',
#     'identifier': [{'value': '56051-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56051-6',
#        'display': 'Hispanic or Latino'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/651'},
#     'effectiveDateTime': '2022-06-26T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3138',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3138',
#     'identifier': [{'value': '32624-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '32624-9',
#        'display': 'Race'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3137',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3137',
#     'identifier': [{'value': '93035-4'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93035-4',
#        'display': "Has season or migrant farm work been your or your family's main source of income at any point in past 2 years [PRAPARE]"}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3136',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3136',
#     'identifier': [{'value': '93034-7'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93034-7',
#        'display': 'Discharged from the U.S. Armed Forces'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3135',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3135',
#     'identifier': [{'value': '54899-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '54899-0',
#        'display': 'Preferred language'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3134',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3134',
#     'identifier': [{'value': '63512-8'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '63512-8',
#        'display': 'How many people are living or staying at this address [#]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3133',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3133',
#     'identifier': [{'value': '71802-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '71802-3',
#        'display': 'Housing status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3132',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3132',
#     'identifier': [{'value': '93033-9'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93033-9',
#        'display': 'Are you worried about losing your housing [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3131',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3131',
#     'identifier': [{'value': '56799-0'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '56799-0',
#        'display': 'Address'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3130',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3130',
#     'identifier': [{'value': '82589-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '82589-3',
#        'display': 'Highest level of education'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3129',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3129',
#     'identifier': [{'value': '93026-3'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '93026-3',
#        'display': 'Do you feel physically and emotionally safe where you currently live [PRAPARE]'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3128',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3128',
#     'identifier': [{'value': '76501-6'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '76501-6',
#        'display': 'Within the last year, have you been afraid of your partner or ex-partner'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}},
#   {'fullUrl': 'http://pwebmedcit.services.brown.edu:9091/fhir/Observation/-3127',
#    'resource': {'resourceType': 'Observation',
#     'id': '-3127',
#     'identifier': [{'value': '72166-2'}],
#     'status': 'final',
#     'category': [{'coding': [{'system': 'http://hl7.org/fhir/observation-category',
#         'code': 'exam'}]}],
#     'code': {'coding': [{'system': 'http://loinc.org',
#        'code': '72166-2',
#        'display': 'Tobacco smoking status'}]},
#     'subject': {'reference': 'Patient/14', 'display': 'ROSARIO HERVEY'},
#     'encounter': {'reference': 'Encounter/618'},
#     'effectiveDateTime': '2020-06-14T00:00:00+00:00',
#     'performer': [{'reference': 'Practitioner/582',
#       'display': 'Rachael540 McKenzie376'}]}}]}

# %%
import requests
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

FHIR_SERVER_BASE_URL = os.getenv("FHIR_SERVER_BASE_URL")
username = os.getenv("FHIR_USERNAME")
password = os.getenv("FHIR_PASSWORD")

def get_fhir_metadata(base_url, credentials):
    url = f"{base_url}/metadata"
    response = requests.get(url, auth=credentials)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to fetch metadata. Status code: {response.status_code}")
        return None

def list_supported_resources(metadata):
    if not metadata:
        print("No metadata available")
        return

    resources = metadata.get('rest', [])[0].get('resource', [])
    supported_resources = [resource['type'] for resource in resources]
    
    print("Supported Resources:")
    for resource in supported_resources:
        print(resource)

if __name__ == "__main__":
    credentials = (username, password)
    metadata = get_fhir_metadata(FHIR_SERVER_BASE_URL, credentials)
    list_supported_resources(metadata)
# Out:
# Supported Resources:
# AllergyIntolerance
# ConceptMap
# Condition
# Device
# DeviceUseStatement
# DocumentReference
# Encounter
# Immunization
# Medication
# MedicationRequest
# MedicationStatement
# Observation
# OperationDefinition
# Organization
# Patient
# Practitioner
# Procedure
# Specimen
